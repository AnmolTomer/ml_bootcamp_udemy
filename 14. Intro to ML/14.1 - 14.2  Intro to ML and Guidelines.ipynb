# %% [markdown]
# # 14.1 What's there in part 2 of this course ?

# %% [markdown]
# From this point onwards second half of the course i.e. Machine Learning from here on referred to as ML starts, each ML algorithm that we will be looking at will consist of 5 parts.
#
# 1. Light Theory Lecture on the topic.
# 2. Optional Supplementary reading assignment.
# 3. Practical Implementation of the ML algorithm in Python.
# 4. Portfolio project exercise.
# 5. Walkthrough for portfolio project for clear understanding.

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 3px  black solid !important;
#   color: black !important;
# }
# # For having gridlines
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 3px  black solid !important;
#   color: black !important;
# }
# # For having gridlines

# %% [markdown]
# # 14.2 Intro to ML and how we will proceed ?

# %% [markdown]
# Throughout the ML section of the course we will be using Introduction to Statistical Learning ISLR by Gareth James as a companion book. This book is freely available online in pdf form and can be obtainer by [clicking here](http://www-bcf.usc.edu/~gareth/ISL/ISLR%20Seventh%20Printing.pdf). Keep in mind term Statistical learning is just a more mathematical way of saying Machine Learning, this book uses R language but do not worry we will be just using mathematical references from this book, you will be given optional reading assignment and you need to read it to get a much more deeper mathematical background behind actually theories and algorithms we learnt throughout the ML section of the course. Say we are discussing Linear Regression then assignment would be to read Chapter 3 of the book which is on the same topic. Remember book is an optional resource for people who are more interested in Mathematics behind ML algorithms.
#
# But on the contrary if you just want light theory and are more interested in Python Applications then you would be fine even without reading. However, we encourage and recommend reading, if not all then on topics you face difficulty to wrap your head around.

# %% [markdown]
# So if you will be reading then task now for you is to read Chapters 1 and 2 before proceeding to ML lectures.
#  ## What is ML ?
#  Machine Learning is a method of data analysis that automates analytical model building. Using algorithms that iteratively learn from data, ML allows computers to find hidden insights without being explicitly programmed where to look.
#
# **Some of the applications of ML are :**
#
# |          **Fraud Detection**          | **Web search results**                  |
# | :-----------------------------------: | --------------------------------------- |
# |    **Real-time ads on web pages**     | **Credit scoring and next-best offers** |
# | **Prediction of equipment failures.** | **New pricing models**                  |
# |    **Network intrusion detection**    | **Recommendation Engines**              |
# |       **Customer Segmentation**       | **Text Sentiment Analysis**             |
# |     **Predicting Customer Churn**     | **Pattern and image recognition.**      |
# |       **Email spam filtering.**       | **Financial Modeling**                  |

# %% [markdown]
# ## ML Process
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Types of ML Algorithms
#
# **There are 3 types of Machine Learning Algorithms**
# * Supervised Learning
#     * You have labelled data and are trying to predict a label based off of known features.
# * Unsupervised Learning
#     * You have unlabelled data and are trying to group together similar data points based off of features
# * Reinforcement Learning
#     * Algorithm learns to perform an action from experience, reward and punishment approach

# %% [markdown]
# ### **Supervised Learning**
#
# Supervised Learning algorithms are trained using labelled examples, such as input where the desired output is known.
# For example, a piece of equipment could have data points failed F or runs "R".
#
# The learning algorithm receives a set of inputs along with the corresponding correct outputs, and the algorithm learns by comparing predicted output with correct output to find errors. It then modifies the model accordingly.
#
# Through methods like classification, regression, prediction and gradient boosting, supervised learning uses patterns to predict the values of the label on additional unlabelled data.
# Supervised learning is used in applications where historical data predicts likely future events.
#
# Example : It can predict when credit card transactions are likely to be fraudulent or which insurance customer is likely to file a claim. Also it can attempt to predict the price of a house based on different features for houses for which we have historical price data.

# %% [markdown]
# ### **Unsupervised Learning**
#
# Unsupervised Learning** is used against data that has no. The system is not told the **"right answer".** The algorithm must figure out what is being shown from given unlabelled data.
#
# The goal is to explore the data and figure out what is being shown. The goal is to explore the data and find some structure within.
#
# Other things which it can do include finding the main attributes that separate customer segments from each other. Popular techniques include **self-organizing maps, nearest-neighbor mapping, k-means clustering and singular value decomposition.**
#
# These algorithms are also used to segment text topics, recommend items and identify data outliers.

# %% [markdown]
# ### **Reinforcement Learning**
#
# **Reinforcement Learning** is often used for robotics, gaming and navigation.
#
# With reinforcement learning the algorithm discovers through trial and error which actions yield the greatest rewards.
#
# This type of learning has three primary components : the agent, (the learner or decision maker), the environment (everything the agent interacts with) and actions (what the agent can do).
#
# The goal for the agent is to choose the action(s) that maximize the expected reward over a given amount of time. The agent will reach the goal much faster by following a good policy.
#
# So goal in reinforcement learning is to learn the best policy.
